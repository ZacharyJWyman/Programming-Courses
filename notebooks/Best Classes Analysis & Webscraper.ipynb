# %% [markdown]
# ## Best Class to take to learn Programming

# %%
#import libraries
import requests
from bs4 import BeautifulSoup
import pandas  as pd
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://www.classcentral.com/subject/programming-and-software-development'

def get_pages(url, number_results):
    pages = []
    pages.append(url)
    total_results = 0
    page_no = 2 #50 results per page 
    while total_results < number_results:
        primary_url = url
        url_extra = '?page='
        mod_url = primary_url + url_extra + str(page_no)
        pages.append(mod_url)
        page_no += 1
        total_results+=50
    return pages

# %%
pages = get_pages(url, 1200)
pages
# Out:
# ['https://www.classcentral.com/subject/programming-and-software-development',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=2',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=3',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=4',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=5',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=6',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=7',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=8',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=9',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=10',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=11',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=12',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=13',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=14',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=15',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=16',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=17',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=18',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=19',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=20',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=21',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=22',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=23',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=24',
#  'https://www.classcentral.com/subject/programming-and-software-development?page=25']

# %%
#init data lists
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []

# %% [markdown]
# ## Defining Functions

# %%
def get_reviews(string):
    index = string.find('Reviews')
    review = string[index - 10: index + 10]
    reviews.append(review.strip())

# %%
def append_institute(institute):
    if institute is not None:
        institutes.append(institute.text.strip())
    else:
        institutes.append(-1)

# %%
def append_provider(provider):
    if provider is not None:
        providers.append(provider.text.strip())
    else:
        providers.append(-1)

# %%
def append_date(date):
    if date is not None:
        dates.append(date.text.strip())
    else:
        dates.append('Self Paced')

# %%
def append_rating(rating):
    if rating is not None:
        ratings.append(rating.text.strip())
    else:
        ratings.append(-1)

# %%
def append_name(name):
    names.append(name)

# %% [markdown]
# ## Web Scraping

# %%
def get_data(pages):
    for page in pages:
        r = requests.get(page)
        soup = BeautifulSoup(r.content, 'html.parser')
        rows = soup.select('tbody tr')

        for row in rows:
            #name
            name = row.select_one('span',{ 'class': 'text-1 line-tight'}).text.strip()
            append_name(name)

            #institute
            institute = row.find('a', {'class': 'color-charcoal small-down-text-2 text-3'})
            append_institute(institute)

            #provider
            provider = row.find('span', {'class': 'hidden medium-up-inline-block'})
            append_provider(provider)

            #date
            date = row.find('td', {'itemprop': 'startDate'})
            append_date(date)

            #reviews
            rev = row.find('span', {'class': 'large-down-hidden block line-tight text-4 color-gray'})
            string = str(rev)
            get_reviews(string)

            #rating
            rating = row.find('span', attrs = {'class': 'xlarge-up-hidden color-charcoal text-center'})
            append_rating(rating)
            
    df = pd.DataFrame({'name': names,
                         'institute': institutes,
                         'provider': providers,
                         'date': dates,
                         'review': reviews,
                         'rating': ratings})
    return df

# %%
programming_df = get_data(pages)

# %%
programming_df
# Out:
#                                                    name  \
# 0                                                    AD
# 1     Programming for Everybody (Getting Started wit...
# 2                                Python Data Structures
# 3     An Introduction to Interactive Programming in ...
# 4                       Using Python to Access Web Data
# ...                                                 ...
# 1395                                  Learn Backbone.js
# 1396                How to create <anything> in Android
# 1397  DEV206.1x: Introduction to XAML and Applicatio...
# 1398                                     程序设计与算法（大学先修课）
# 1399                    Firebase Essentials For Android
#
#                          institute  provider            date         review  \
# 0     Kellogg School of Management        -1      Self Paced           None
# 1           University of Michigan  Coursera   3rd Aug, 2020  20572 Reviews
# 2           University of Michigan  Coursera  17th Aug, 2020   7913 Reviews
# 3                  Rice University  Coursera  17th Aug, 2020   3241 Reviews
# 4           University of Michigan  Coursera   3rd Aug, 2020   2880 Reviews
# ...                            ...       ...             ...            ...
# 1395                            -1   Udacity  18th Aug, 2015           None
# 1396                            -1   Udacity  10th Sep, 2015           None
# 1397                     Microsoft       edX      Self Paced           None
# 1398             Peking University  Coursera   8th Oct, 2015           None
# 1399                        Google   Udacity   1st Dec, 2015           None
#
#      rating
# 0       5.0
# 1       4.9
# 2       4.9
# 3       4.9
# 4       4.7
# ...     ...
# 1395     -1
# 1396     -1
# 1397     -1
# 1398     -1
# 1399     -1
#
# [1400 rows x 6 columns]

# %%
#dump data from scrape into csv
#programming_df.to_csv(r'D:\Data Science\Best Programming Course\scraped.csv')

# %% [markdown]
# ## Clean DataFrame

# %%
def clean(df):
    #df.drop('Unnamed: 0', axis=1, inplace=True) #only need if reading from csv.
    df = df[df['name'] != 'AD']
    df = df[df['rating'] != -1]
    df.loc[df['institute'] == '-1', 'institute'] = None
    df.drop_duplicates(inplace = True)
    return df

# %%
programming_df = clean(programming_df)
programming_df
# Out:
#                                                    name  \
# 1     Programming for Everybody (Getting Started wit...
# 2                                Python Data Structures
# 3     An Introduction to Interactive Programming in ...
# 4                       Using Python to Access Web Data
# 6                           Using Databases with Python
# ...                                                 ...
# 1381                   Programmation sur iPhone et iPad
# 1382                 Developing Scalable Apps in Python
# 1383                  Android Development for Beginners
# 1388           Interactive Computer Graphics with WebGL
# 1391  JDK 8 Massive Open and Online Course: Lambdas ...
#
#                      institute                     provider            date  \
# 1       University of Michigan                     Coursera   3rd Aug, 2020
# 2       University of Michigan                     Coursera  17th Aug, 2020
# 3              Rice University                     Coursera  17th Aug, 2020
# 4       University of Michigan                     Coursera   3rd Aug, 2020
# 6       University of Michigan                     Coursera   3rd Aug, 2020
# ...                        ...                          ...             ...
# 1381      Sorbonne Universités  France Université Numerique  16th Apr, 2015
# 1382                    Google                      Udacity  30th Apr, 2015
# 1383                    Google                      Udacity  11th May, 2015
# 1388  University of New Mexico                     Coursera  29th Jun, 2015
# 1391                    Oracle                  Independent  14th Jul, 2015
#
#              review rating
# 1     20572 Reviews    4.9
# 2      7913 Reviews    4.9
# 3      3241 Reviews    4.9
# 4      2880 Reviews    4.7
# 6      2306 Reviews    4.7
# ...             ...    ...
# 1381      1 Reviews    4.0
# 1382      1 Reviews    4.0
# 1383     23 Reviews    4.3
# 1388      2 Reviews    4.5
# 1391      6 Reviews    4.8
#
# [354 rows x 6 columns]

# %%
#We need to get rid of rows with less than 5 reviews as low reviews and high rating can be misleading.
def get_rating(df):
    highest_rated = df.sort_values('rating', ascending = False)
    reviews_int = highest_rated['review'].map(lambda x: x.rstrip('Reviews')).astype(int)
    highest_rated['review'] = pd.DataFrame(reviews_int)
    highest_rated = highest_rated[highest_rated['review'] >= 5]
    return highest_rated

# %%
programming_rate = get_rating(programming_df)
programming_rate
# Out:
#                                                   name  \
# 38        HTML, CSS, and Javascript for Web Developers
# 2                               Python Data Structures
# 830                            Fundamentals of NetLogo
# 1    Programming for Everybody (Getting Started wit...
# 7                                 Python for Everybody
# ..                                                 ...
# 74                  Cloud Computing Basics (Cloud 101)
# 641                      Intro to Relational Databases
# 105                  Introduction To Swift Programming
# 961                                       Advanced C++
# 774                                C++ For Programmers
#
#                     institute             provider            date  review  \
# 38   Johns Hopkins University             Coursera  24th Aug, 2020      17
# 2      University of Michigan             Coursera  17th Aug, 2020    7913
# 830        Santa Fe Institute  Complexity Explorer      Self Paced       7
# 1      University of Michigan             Coursera   3rd Aug, 2020   20572
# 7      University of Michigan             Coursera      Self Paced     342
# ..                        ...                  ...             ...     ...
# 74                 LearnQuest             Coursera  31st Aug, 2020       9
# 641                        -1              Udacity      Self Paced       7
# 105     University of Toronto             Coursera  17th Aug, 2020       7
# 961                 Microsoft                  edX      Self Paced       7
# 774                        -1              Udacity      Self Paced       6
#
#     rating
# 38     5.0
# 2      4.9
# 830    4.9
# 1      4.9
# 7      4.9
# ..     ...
# 74     2.2
# 641    2.1
# 105    1.3
# 961    1.3
# 774    1.2
#
# [128 rows x 6 columns]

# %% [markdown]
# ## Data Retrieval

# %% [markdown]
# Now that we have some functions set up to streamline the process we can webscrape data from different domains on the same website.

# %%
#Functions: get_pages(url, # results), run webscraper: get_data(pages), clean(df), get_rating(df)
dataframes = []
dataframes.append(programming_rate)

# %%
#python courses
pages = get_pages('https://www.classcentral.com/subject/python', 200)
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []
python_df = get_data(pages)
python_df = clean(python_df)
python_rate = get_rating(python_df)
dataframes.append(python_rate)

# %%
#machine learning courses
pages = get_pages('https://www.classcentral.com/subject/machine-learning', 250)
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []
ml_df = get_data(pages)
ml_df = clean(ml_df)
ml_rate = get_rating(ml_df)
dataframes.append(ml_rate)

# %%
#data science courses
pages = get_pages('https://www.classcentral.com/subject/data-science', 600)
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []
ds_df = get_data(pages)
ds_df = clean(ds_df)
ds_rate = get_rating(ds_df)
dataframes.append(ds_rate)

# %%
#computer science courses
pages = get_pages('https://www.classcentral.com/subject/cs', 1800)
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []
cs_df = get_data(pages)
cs_df = clean(cs_df)
cs_rate = get_rating(cs_df)
dataframes.append(cs_rate)

# %%
#stats and probability courses
pages = get_pages('https://www.classcentral.com/subject/statistics', 150)
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []
stats_df = get_data(pages)
stats_df = clean(stats_df)
stats_rate = get_rating(stats_df)
dataframes.append(stats_rate)

# %%
#artificial intelligence courses
pages = get_pages('https://www.classcentral.com/subject/ai', 300)
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []
ai_df = get_data(pages)
ai_df = clean(ai_df)
ai_rate = get_rating(ai_df)
dataframes.append(ai_rate)

# %%
#data analysis courses
pages = get_pages('https://www.classcentral.com/subject/data-analysis', 150)
names = []
institutes = []
providers = []
dates = []
reviews = []
ratings = []
da_df = get_data(pages)
da_df = clean(da_df)
da_rate = get_rating(da_df)
dataframes.append(da_rate)

# %% [markdown]
# Now that we have some data to work with we can create some visuals.

# %%
for df in dataframes:
# Out:
# 9
